# %%
#Storage account key is stored in Azure Key-Vault as a sceret. The secret name is blobstoragesecret and KeyVaultScope is the name of the scope we have created. We can also store the storage account name as a new secret if we don't want users to know the name of the storage account.

storageAccount="cookbookblobstorage1"
storageKey = dbutils.secrets.get(scope="KeyVaultScope",key="blobstoragesecret")
mountpoint = "/mnt/KeyVaultBlob"
storageEndpoint =   "wasbs://rawdata@{}.blob.core.windows.net".format(storageAccount)
storageConnSting = "fs.azure.account.key.{}.blob.core.windows.net".format(storageAccount)

try:
  dbutils.fs.mount(
  source = storageEndpoint,
  mount_point = mountpoint,
  extra_configs = {storageConnSting:storageKey})
except:
    print("Already mounted...."+mountpoint)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Already mounted..../mnt/KeyVaultBlob
# </div>

# %%
# %fs ls /mnt/KeyVaultBlob
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th><th>name</th><th>size</th></tr></thead><tbody><tr><td>dbfs:/mnt/KeyVaultBlob/Customer/</td><td>Customer/</td><td>0</td></tr><tr><td>dbfs:/mnt/KeyVaultBlob/Vehicle_Agg/</td><td>Vehicle_Agg/</td><td>0</td></tr><tr><td>dbfs:/mnt/KeyVaultBlob/Vehicle_Chkpoint/</td><td>Vehicle_Chkpoint/</td><td>0</td></tr><tr><td>dbfs:/mnt/KeyVaultBlob/VehiclechkpointKafkaEventHub_Delta_Agg_Delta11/</td><td>VehiclechkpointKafkaEventHub_Delta_Agg_Delta11/</td><td>0</td></tr><tr><td>dbfs:/mnt/KeyVaultBlob/VehiclechkpointKafkaEventHub_Delta_Agg_Parquet/</td><td>VehiclechkpointKafkaEventHub_Delta_Agg_Parquet/</td><td>0</td></tr><tr><td>dbfs:/mnt/KeyVaultBlob/VehiclechkpointKafkaEventHub_Delta_Agg_Parquet1/</td><td>VehiclechkpointKafkaEventHub_Delta_Agg_Parquet1/</td><td>0</td></tr><tr><td>dbfs:/mnt/KeyVaultBlob/VehiclechkpointKafkaEventHub_Delta_Agg_Parquet2/</td><td>VehiclechkpointKafkaEventHub_Delta_Agg_Parquet2/</td><td>0</td></tr><tr><td>dbfs:/mnt/KeyVaultBlob/VehiclechkpointKafkaEventHub_Delta_Agg_Tumbling/</td><td>VehiclechkpointKafkaEventHub_Delta_Agg_Tumbling/</td><td>0</td></tr><tr><td>dbfs:/mnt/KeyVaultBlob/Vehiclechkpointkafkaeventhub_Agg_Chkpoint_Delta11/</td><td>Vehiclechkpointkafkaeventhub_Agg_Chkpoint_Delta11/</td><td>0</td></tr><tr><td>dbfs:/mnt/KeyVaultBlob/Vehiclechkpointkafkaeventhub_Agg_Chkpoint_Tumbling/</td><td>Vehiclechkpointkafkaeventhub_Agg_Chkpoint_Tumbling/</td><td>0</td></tr><tr><td>dbfs:/mnt/KeyVaultBlob/Vehiclechkpointkafkaeventhub_Agg_Chkpoint_Tumbling1/</td><td>Vehiclechkpointkafkaeventhub_Agg_Chkpoint_Tumbling1/</td><td>0</td></tr><tr><td>dbfs:/mnt/KeyVaultBlob/Vehiclechkpointkafkaeventhub_Agg_Chkpoint_parquet/</td><td>Vehiclechkpointkafkaeventhub_Agg_Chkpoint_parquet/</td><td>0</td></tr><tr><td>dbfs:/mnt/KeyVaultBlob/test/</td><td>test/</td><td>0</td></tr></tbody></table></div>

# %%
display(dbutils.fs.ls("/mnt/KeyVaultBlob/Customer/parquetFiles"))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th><th>name</th><th>size</th></tr></thead><tbody><tr><td>dbfs:/mnt/KeyVaultBlob/Customer/parquetFiles/part-00000-tid-7877307066025976411-3a62bd06-bc9c-467f-ae7b-d5db8ca40833-56-1-c000.snappy.parquet</td><td>part-00000-tid-7877307066025976411-3a62bd06-bc9c-467f-ae7b-d5db8ca40833-56-1-c000.snappy.parquet</td><td>1232348</td></tr><tr><td>dbfs:/mnt/KeyVaultBlob/Customer/parquetFiles/part-00001-tid-7877307066025976411-3a62bd06-bc9c-467f-ae7b-d5db8ca40833-57-1-c000.snappy.parquet</td><td>part-00001-tid-7877307066025976411-3a62bd06-bc9c-467f-ae7b-d5db8ca40833-57-1-c000.snappy.parquet</td><td>1232940</td></tr><tr><td>dbfs:/mnt/KeyVaultBlob/Customer/parquetFiles/part-00002-tid-7877307066025976411-3a62bd06-bc9c-467f-ae7b-d5db8ca40833-58-1-c000.snappy.parquet</td><td>part-00002-tid-7877307066025976411-3a62bd06-bc9c-467f-ae7b-d5db8ca40833-58-1-c000.snappy.parquet</td><td>1234397</td></tr><tr><td>dbfs:/mnt/KeyVaultBlob/Customer/parquetFiles/part-00003-tid-7877307066025976411-3a62bd06-bc9c-467f-ae7b-d5db8ca40833-59-1-c000.snappy.parquet</td><td>part-00003-tid-7877307066025976411-3a62bd06-bc9c-467f-ae7b-d5db8ca40833-59-1-c000.snappy.parquet</td><td>1233382</td></tr><tr><td>dbfs:/mnt/KeyVaultBlob/Customer/parquetFiles/part-00004-tid-7877307066025976411-3a62bd06-bc9c-467f-ae7b-d5db8ca40833-60-1-c000.snappy.parquet</td><td>part-00004-tid-7877307066025976411-3a62bd06-bc9c-467f-ae7b-d5db8ca40833-60-1-c000.snappy.parquet</td><td>1232687</td></tr><tr><td>dbfs:/mnt/KeyVaultBlob/Customer/parquetFiles/part-00005-tid-7877307066025976411-3a62bd06-bc9c-467f-ae7b-d5db8ca40833-61-1-c000.snappy.parquet</td><td>part-00005-tid-7877307066025976411-3a62bd06-bc9c-467f-ae7b-d5db8ca40833-61-1-c000.snappy.parquet</td><td>1235305</td></tr><tr><td>dbfs:/mnt/KeyVaultBlob/Customer/parquetFiles/part-00006-tid-7877307066025976411-3a62bd06-bc9c-467f-ae7b-d5db8ca40833-62-1-c000.snappy.parquet</td><td>part-00006-tid-7877307066025976411-3a62bd06-bc9c-467f-ae7b-d5db8ca40833-62-1-c000.snappy.parquet</td><td>1233292</td></tr><tr><td>dbfs:/mnt/KeyVaultBlob/Customer/parquetFiles/part-00007-tid-7877307066025976411-3a62bd06-bc9c-467f-ae7b-d5db8ca40833-63-1-c000.snappy.parquet</td><td>part-00007-tid-7877307066025976411-3a62bd06-bc9c-467f-ae7b-d5db8ca40833-63-1-c000.snappy.parquet</td><td>1233605</td></tr><tr><td>dbfs:/mnt/KeyVaultBlob/Customer/parquetFiles/part-00008-tid-7877307066025976411-3a62bd06-bc9c-467f-ae7b-d5db8ca40833-64-1-c000.snappy.parquet</td><td>part-00008-tid-7877307066025976411-3a62bd06-bc9c-467f-ae7b-d5db8ca40833-64-1-c000.snappy.parquet</td><td>1231438</td></tr><tr><td>dbfs:/mnt/KeyVaultBlob/Customer/parquetFiles/part-00009-tid-7877307066025976411-3a62bd06-bc9c-467f-ae7b-d5db8ca40833-65-1-c000.snappy.parquet</td><td>part-00009-tid-7877307066025976411-3a62bd06-bc9c-467f-ae7b-d5db8ca40833-65-1-c000.snappy.parquet</td><td>1238351</td></tr></tbody></table></div>

# %%
#Lets read data from csv file which is copied to Blob Storage
df_cust= spark.read.format("parquet").option("header",True).load("dbfs:/mnt/KeyVaultBlob/Customer/parquetFiles/*.parquet")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
display(df_cust.limit(10))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>C_CUSTKEY</th><th>C_NAME</th><th>C_ADDRESS</th><th>C_NATIONKEY</th><th>C_PHONE</th><th>C_ACCTBAL</th><th>C_MKTSEGMENT</th><th>C_COMMENT</th></tr></thead><tbody><tr><td>34136</td><td>Customer#000034136</td><td>UjBY ZyJnHesu0bxL0VEvU1t1A</td><td>0</td><td>10-863-612-2949</td><td>3397.87</td><td>BUILDING</td><td>es. furiously fluffy instructions </td></tr><tr><td>31731</td><td>Customer#000031731</td><td>Zq9KcCB7jMCIGMj32les8l9QR4laAZyaxWga6</td><td>0</td><td>10-250-546-6987</td><td>8466.07</td><td>FURNITURE</td><td>counts lose quickly at the blithely regular dependencies</td></tr><tr><td>33511</td><td>Customer#000033511</td><td>bz2D0HrwQiaz</td><td>0</td><td>10-618-323-6263</td><td>5331.22</td><td>AUTOMOBILE</td><td>ons are slyly instructions. carefully final theodolites </td></tr><tr><td>45695</td><td>Customer#000045695</td><td>Oc2Yin5Gcqudb6RGEWEfJPTKcUNqOOrVC147</td><td>0</td><td>10-414-601-9544</td><td>5340.52</td><td>AUTOMOBILE</td><td>riously furious pinto beans cajole carefully express ideas. even re</td></tr><tr><td>36768</td><td>Customer#000036768</td><td>,8Q8TZ48Wme</td><td>0</td><td>10-950-600-3087</td><td>9229.21</td><td>MACHINERY</td><td>ounts engage quickly sly accounts. carefully ironic accounts na</td></tr><tr><td>37449</td><td>Customer#000037449</td><td>kSezsusukDqm37pMNI0bRMFUDyH6h0GekQbTfl</td><td>0</td><td>10-231-238-1522</td><td>1173.53</td><td>AUTOMOBILE</td><td>ding dependencies shall promise ironic deposits. carefully special braids haggle blithely regular pac</td></tr><tr><td>46970</td><td>Customer#000046970</td><td>uZbY1HQYjGobtk8ppkV</td><td>0</td><td>10-361-617-6664</td><td>8689.85</td><td>AUTOMOBILE</td><td>xes boost furiously regular platelets. sly, unusual platelets along the blithely special requests are</td></tr><tr><td>29109</td><td>Customer#000029109</td><td>FG6PVFkL69,LZWcl4JvrVrMVBUDmckSRadTylcua</td><td>0</td><td>10-770-489-7404</td><td>1939.54</td><td>AUTOMOBILE</td><td> above the furiously regular theodolite</td></tr><tr><td>43753</td><td>Customer#000043753</td><td>xWtHn81QCu6kSjIkdYyW4RNSoS0g9 </td><td>0</td><td>10-180-882-4254</td><td>4975.15</td><td>AUTOMOBILE</td><td>sts-- idly final forges according to the foxes use fluffily alongside of the carefully ironic packag</td></tr><tr><td>42429</td><td>Customer#000042429</td><td>g6AgY9ecZcwMhWvq5rT7qT gNFno5v4jG2ZrWq</td><td>0</td><td>10-616-749-7989</td><td>5345.32</td><td>BUILDING</td><td>ing to the slyly pending requests. sentiments are furiously across the qui</td></tr></tbody></table></div>

# %%
df_cust.count()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[5]: 150000</div>
