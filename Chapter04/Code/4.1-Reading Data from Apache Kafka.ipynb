# %%
from pyspark.sql.functions import *
from pyspark.sql.types import *
from datetime import datetime
from pyspark.sql.functions  import from_unixtime
from pyspark.sql.functions  import to_date
from pyspark.sql import Row
from pyspark.sql.functions import to_json, struct
from pyspark.sql import functions as F
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
#Creating the schema for the vehicle data json structure
jsonschema = StructType() \
.add("id", StringType()) \
.add("timestamp", TimestampType()) \
.add("rpm", IntegerType()) \
.add("speed", IntegerType()) \
.add("kms", IntegerType())
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# We can use to this to reset the offset from where we want to start reading data from kafak provided data in that offset is available in Kafka Source
offset = '''
  {
  "VehicleDetails":{"0": 1}
  }
'''

print(offset)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">
#   {
#   &#34;VehicleDetails&#34;:{&#34;0&#34;: 1}
#   }
#
# </div>

# %%
#Reading data from kafka source
kafkaDF = spark.readStream.format("kafka") \
.option("kafka.bootstrap.servers", "10.1.0.13:9092,10.1.0.11:9092") \
.option("subscribe", "VehicleDetails") \
.option("group.id", "Cookbook-demo") \
.option("startingOffsets","latest" ) \
.load()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
#Checking if streaming is on and getting the schema for the kakfa dataframe 
print( kafkaDF.isStreaming)
print( kafkaDF.printSchema())
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">True
# root
# -- key: binary (nullable = true)
# -- value: binary (nullable = true)
# -- topic: string (nullable = true)
# -- partition: integer (nullable = true)
# -- offset: long (nullable = true)
# -- timestamp: timestamp (nullable = true)
# -- timestampType: integer (nullable = true)
#
# None
# </div>

# %%
# display(kafkaDF.selectExpr("CAST(key AS STRING)", "CAST(value AS STRING)"))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
#Converting binary datatype to string for the dataframe columns. Without this you cannot use from_json function as it expects the column datatype as string not binary
newkafkaDF=kafkaDF.selectExpr("CAST(key AS STRING)", "CAST(value AS STRING)")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
#Adding new column vehiclejson which is a struct and has 5 columns id, timestamp,rpm,speed and kms
newkafkaDF=newkafkaDF.withColumn('vehiclejson', from_json(col('value'),schema=jsonschema))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
kafkajsonDF=newkafkaDF.select("key","value", "vehiclejson.*")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
#you can run the below command to view the column values
#display(kafkajsonDF)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
#Writing the streaming data to Delta tables
#Location for Delta table is dbfs:/Vehiclechkpoint_Delta. We are using default mount point which is available in Databricks cluster. You can use your own mount point as well. Recommended is to mount external ADLS Gen-2 file system 
kafkajsonDF.selectExpr(
                  "id"	  \
                  ,"timestamp"	   \
                  ,"rpm"	\
                  ,"speed" \
                  ,"kms" ) \
.writeStream.format("delta") \
.outputMode("append") \
.option("checkpointLocation", "dbfs:/Vehiclechkpoint_Demo/") \
.option("mergeSchema", "true") \
.start("dbfs:/Vehiclechkpoint_Delta")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[29]: &lt;pyspark.sql.streaming.StreamingQuery at 0x7f47c10d3bd0&gt;</div>

# %%
# %sql
-- Creating the table on delta location
CREATE TABLE IF NOT EXISTS VehicleDetails_Delta
USING DELTA
LOCATION "dbfs:/Vehiclechkpoint_Delta/"
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>

# %%
# %sql
--select * from VehicleDetails order by timestamp desc limit 20 --2021-03-03T01:32:36.100+0000
--select * from VehicleDetails_Delta limit 10
select count(*) from VehicleDetails_Delta--1200
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>count(1)</th></tr></thead><tbody><tr><td>2000</td></tr></tbody></table></div>

# %%
#Creating folder for parquet file in default dbfs location
dbutils.fs.mkdirs("dbfs:/VehiclechData/parquetFiles/")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[30]: True</div>

# %%
dbutils.fs.ls("dbfs:/VehiclechData")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[31]: [FileInfo(path=&#39;dbfs:/VehiclechData/csv/&#39;, name=&#39;csv/&#39;, size=0),
#  FileInfo(path=&#39;dbfs:/VehiclechData/parquetFiles/&#39;, name=&#39;parquetFiles/&#39;, size=0),
#  FileInfo(path=&#39;dbfs:/VehiclechData/parquetFiles1/&#39;, name=&#39;parquetFiles1/&#39;, size=0)]</div>

# %%
kafkajsonDF.selectExpr(
                  "id"	  \
                  ,"timestamp"	   \
                  ,"rpm"	\
                  ,"speed" \
                  ,"kms" ) \
.writeStream.format("parquet").queryName("veh_details").option("checkpointLocation", "dbfs:/Vehiclechkpoint_Demo_Parquet1/").start("dbfs:/VehiclechData/parquetFiles")#.awaitTermination()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[32]: &lt;pyspark.sql.streaming.StreamingQuery at 0x7f47c1035410&gt;</div>

# %%
# %fs ls dbfs:/VehiclechData/parquetFiles
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th><th>name</th><th>size</th></tr></thead><tbody><tr><td>dbfs:/VehiclechData/parquetFiles/_spark_metadata/</td><td>_spark_metadata/</td><td>0</td></tr><tr><td>dbfs:/VehiclechData/parquetFiles/part-00000-01bbb09a-e774-488c-8534-7d96ec8e7b77-c000.snappy.parquet</td><td>part-00000-01bbb09a-e774-488c-8534-7d96ec8e7b77-c000.snappy.parquet</td><td>1657</td></tr><tr><td>dbfs:/VehiclechData/parquetFiles/part-00000-03206e9c-9811-4fe2-b185-ba176e739627-c000.snappy.parquet</td><td>part-00000-03206e9c-9811-4fe2-b185-ba176e739627-c000.snappy.parquet</td><td>1692</td></tr><tr><td>dbfs:/VehiclechData/parquetFiles/part-00000-0614e2d2-4167-4f68-8436-147ade5d78de-c000.snappy.parquet</td><td>part-00000-0614e2d2-4167-4f68-8436-147ade5d78de-c000.snappy.parquet</td><td>3743</td></tr><tr><td>dbfs:/VehiclechData/parquetFiles/part-00000-06604ed0-1416-4f46-a0f7-62e59dc28524-c000.snappy.parquet</td><td>part-00000-06604ed0-1416-4f46-a0f7-62e59dc28524-c000.snappy.parquet</td><td>1692</td></tr><tr><td>dbfs:/VehiclechData/parquetFiles/part-00000-17dfcf25-b469-4f1a-b20e-41d1af482242-c000.snappy.parquet</td><td>part-00000-17dfcf25-b469-4f1a-b20e-41d1af482242-c000.snappy.parquet</td><td>3765</td></tr><tr><td>dbfs:/VehiclechData/parquetFiles/part-00000-31c35cee-70fb-4776-9cc7-40e463f7dbc5-c000.snappy.parquet</td><td>part-00000-31c35cee-70fb-4776-9cc7-40e463f7dbc5-c000.snappy.parquet</td><td>1808</td></tr><tr><td>dbfs:/VehiclechData/parquetFiles/part-00000-3ba692b2-9c79-4dcf-87a0-d001c26f2d4a-c000.snappy.parquet</td><td>part-00000-3ba692b2-9c79-4dcf-87a0-d001c26f2d4a-c000.snappy.parquet</td><td>1604</td></tr><tr><td>dbfs:/VehiclechData/parquetFiles/part-00000-43363fed-5ecb-4a7f-a373-1e456bc097ba-c000.snappy.parquet</td><td>part-00000-43363fed-5ecb-4a7f-a373-1e456bc097ba-c000.snappy.parquet</td><td>3783</td></tr><tr><td>dbfs:/VehiclechData/parquetFiles/part-00000-45604f0f-482c-4b4d-a106-084c9b5d41fd-c000.snappy.parquet</td><td>part-00000-45604f0f-482c-4b4d-a106-084c9b5d41fd-c000.snappy.parquet</td><td>3718</td></tr><tr><td>dbfs:/VehiclechData/parquetFiles/part-00000-4a9a095d-56c1-44be-a764-238ed4e55cee-c000.snappy.parquet</td><td>part-00000-4a9a095d-56c1-44be-a764-238ed4e55cee-c000.snappy.parquet</td><td>3763</td></tr><tr><td>dbfs:/VehiclechData/parquetFiles/part-00000-4de5b97a-3646-4ff0-ad7b-0cc685c03575-c000.snappy.parquet</td><td>part-00000-4de5b97a-3646-4ff0-ad7b-0cc685c03575-c000.snappy.parquet</td><td>1709</td></tr><tr><td>dbfs:/VehiclechData/parquetFiles/part-00000-8fb2a061-364d-4eb2-9e87-0cd01f69676e-c000.snappy.parquet</td><td>part-00000-8fb2a061-364d-4eb2-9e87-0cd01f69676e-c000.snappy.parquet</td><td>631</td></tr><tr><td>dbfs:/VehiclechData/parquetFiles/part-00000-95e56587-336f-422d-acaf-2acd59e13dd9-c000.snappy.parquet</td><td>part-00000-95e56587-336f-422d-acaf-2acd59e13dd9-c000.snappy.parquet</td><td>3744</td></tr><tr><td>dbfs:/VehiclechData/parquetFiles/part-00000-9d4d2139-63ec-4633-8c21-7837e48858f9-c000.snappy.parquet</td><td>part-00000-9d4d2139-63ec-4633-8c21-7837e48858f9-c000.snappy.parquet</td><td>1692</td></tr><tr><td>dbfs:/VehiclechData/parquetFiles/part-00000-d74b6936-7e54-4506-aaf4-54417274a713-c000.snappy.parquet</td><td>part-00000-d74b6936-7e54-4506-aaf4-54417274a713-c000.snappy.parquet</td><td>1553</td></tr></tbody></table></div>
