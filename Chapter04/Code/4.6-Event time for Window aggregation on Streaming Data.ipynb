# %%
from pyspark.sql.functions import *
from pyspark.sql.types import *
from datetime import datetime
from pyspark.sql.functions  import from_unixtime
from pyspark.sql.functions  import to_date
from pyspark.sql import Row
from pyspark.sql.functions import to_json, struct
from pyspark.sql import functions as F
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
#Creating the schema for the vehicle data json structure
jsonschema = StructType() \
.add("id", StringType()) \
.add("timestamp", TimestampType()) \
.add("rpm", IntegerType()) \
.add("speed", IntegerType()) \
.add("kms", IntegerType())
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
#  We are reading from kafkaenabledhub1. Please change this value if you are using a different EventHub name in the Python script.
TOPIC = "kafkaenabledhub1"
BOOTSTRAP_SERVERS = "kafkaenabledeventhubns.servicebus.windows.net:9093"
EH_SASL = "kafkashaded.org.apache.kafka.common.security.plain.PlainLoginModule required username=\"$ConnectionString\" password=\"Endpoint=sb://kafkaenabledeventhubns.servicebus.windows.net/;SharedAccessKeyName=sendreceivekafka;SharedAccessKey=FLdyRBpyGt6Pluis5b79vRTwuHOy/OjwijF7jsCmFnA=\";"
GROUP_ID = "$Default"

# // Read stream using Spark SQL (structured streaming)
# // consider adding .option("startingOffsets", "earliest") to read earliest available offset during testing
kafkaDF = spark.readStream \
    .format("kafka") \
    .option("subscribe", TOPIC) \
    .option("kafka.bootstrap.servers", BOOTSTRAP_SERVERS) \
    .option("kafka.sasl.mechanism", "PLAIN") \
    .option("kafka.security.protocol", "SASL_SSL") \
    .option("kafka.sasl.jaas.config", EH_SASL) \
    .option("kafka.request.timeout.ms", "60000") \
    .option("kafka.session.timeout.ms", "60000") \
    .option("kafka.group.id", GROUP_ID) \
    .option("failOnDataLoss", "false") \
    .option("startingOffsets", "latest") \
    .load()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
#Converting binary datatype to string for the dataframe columns. Without this you cannot use from_json function as it expects the column datatype as string not binary
kafkaDF=kafkaDF.selectExpr("CAST(key AS STRING)", "CAST(value AS STRING)")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
#Adding new column vehiclejson which is a struct and has 5 columns id, timestamp,rpm,speed and kms
newkafkaDF=kafkaDF.withColumn('vehiclejson', from_json(col('value'),schema=jsonschema))
kafkajsonDF=newkafkaDF.select("key","value", "vehiclejson.*")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
#you can uncomment and run the below command to view the column values
# display(kafkajsonDF)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# ### Tumbling window non-overlapping event time

# %%
kafkajsonDF.groupBy(window('timestamp',"1 minutes"),'id').count().orderBy('window') \
.writeStream.format("delta") \
.outputMode("complete") \
.option("truncate", "false") \
.option("checkpointLocation", "dbfs:/Vehiclechkpointkafkaeventhub_Agg_Chkpoint_Tumbling1/") \
.option("mergeSchema", "true") \
.start("dbfs:/VehiclechkpointKafkaEventHub_Delta_Agg_Tumbling1")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[8]: &lt;pyspark.sql.streaming.StreamingQuery at 0x7fdcffbd4a50&gt;</div>

# %%
# %sql
DROP TABLE IF EXISTS VehiclechkpointKafkaEventHub_Delta_Agg_Tumbling;
CREATE TABLE IF NOT EXISTS VehiclechkpointKafkaEventHub_Delta_Agg_Tumbling
USING DELTA
LOCATION "dbfs:/VehiclechkpointKafkaEventHub_Delta_Agg_Tumbling1/"
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>

# %%
# %sql
SELECT * FROM VehiclechkpointKafkaEventHub_Delta_Agg_Tumbling ORDER BY Window desc
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>window</th><th>id</th><th>count</th></tr></thead><tbody><tr><td>List(2021-07-30T01:55:00.000+0000, 2021-07-30T01:56:00.000+0000)</td><td>a529fb2a-5f7c-4aa1-976c-e4b683b919f2</td><td>1</td></tr><tr><td>List(2021-07-30T01:55:00.000+0000, 2021-07-30T01:56:00.000+0000)</td><td>67f5187f-d1c0-431b-844a-2f99f49d59e3</td><td>1</td></tr><tr><td>List(2021-07-30T01:55:00.000+0000, 2021-07-30T01:56:00.000+0000)</td><td>afa56211-c75c-4d76-9f17-2e550cd51fa8</td><td>2</td></tr><tr><td>List(2021-07-30T01:55:00.000+0000, 2021-07-30T01:56:00.000+0000)</td><td>66ce2ce6-3b23-4f92-a3b7-a7dfd3fe7caf</td><td>1</td></tr><tr><td>List(2021-07-30T01:55:00.000+0000, 2021-07-30T01:56:00.000+0000)</td><td>45e71b4f-f46e-4e58-959d-e2afa7830875</td><td>2</td></tr><tr><td>List(2021-07-30T01:55:00.000+0000, 2021-07-30T01:56:00.000+0000)</td><td>19eeda6f-0489-4c68-937a-f91ba866643b</td><td>1</td></tr><tr><td>List(2021-07-30T01:55:00.000+0000, 2021-07-30T01:56:00.000+0000)</td><td>e6a2c890-16f7-4dc8-b062-33b3e44b5c3a</td><td>2</td></tr><tr><td>List(2021-07-30T01:55:00.000+0000, 2021-07-30T01:56:00.000+0000)</td><td>a1a4b4ba-7f9c-4058-aa15-b79f3fd5dd7d</td><td>2</td></tr><tr><td>List(2021-07-30T01:55:00.000+0000, 2021-07-30T01:56:00.000+0000)</td><td>c91ff0d5-bffc-458f-9a15-25fac0fc6cc8</td><td>1</td></tr><tr><td>List(2021-07-30T01:55:00.000+0000, 2021-07-30T01:56:00.000+0000)</td><td>c7bb7aa9-cc1c-453f-a86e-ca171c710e85</td><td>2</td></tr><tr><td>List(2021-07-30T01:54:00.000+0000, 2021-07-30T01:55:00.000+0000)</td><td>a1a4b4ba-7f9c-4058-aa15-b79f3fd5dd7d</td><td>10</td></tr><tr><td>List(2021-07-30T01:54:00.000+0000, 2021-07-30T01:55:00.000+0000)</td><td>c7bb7aa9-cc1c-453f-a86e-ca171c710e85</td><td>10</td></tr><tr><td>List(2021-07-30T01:54:00.000+0000, 2021-07-30T01:55:00.000+0000)</td><td>67f5187f-d1c0-431b-844a-2f99f49d59e3</td><td>10</td></tr><tr><td>List(2021-07-30T01:54:00.000+0000, 2021-07-30T01:55:00.000+0000)</td><td>e6a2c890-16f7-4dc8-b062-33b3e44b5c3a</td><td>10</td></tr><tr><td>List(2021-07-30T01:54:00.000+0000, 2021-07-30T01:55:00.000+0000)</td><td>afa56211-c75c-4d76-9f17-2e550cd51fa8</td><td>9</td></tr><tr><td>List(2021-07-30T01:54:00.000+0000, 2021-07-30T01:55:00.000+0000)</td><td>a529fb2a-5f7c-4aa1-976c-e4b683b919f2</td><td>10</td></tr><tr><td>List(2021-07-30T01:54:00.000+0000, 2021-07-30T01:55:00.000+0000)</td><td>19eeda6f-0489-4c68-937a-f91ba866643b</td><td>10</td></tr><tr><td>List(2021-07-30T01:54:00.000+0000, 2021-07-30T01:55:00.000+0000)</td><td>66ce2ce6-3b23-4f92-a3b7-a7dfd3fe7caf</td><td>10</td></tr><tr><td>List(2021-07-30T01:54:00.000+0000, 2021-07-30T01:55:00.000+0000)</td><td>45e71b4f-f46e-4e58-959d-e2afa7830875</td><td>10</td></tr><tr><td>List(2021-07-30T01:54:00.000+0000, 2021-07-30T01:55:00.000+0000)</td><td>c91ff0d5-bffc-458f-9a15-25fac0fc6cc8</td><td>10</td></tr><tr><td>List(2021-07-30T01:53:00.000+0000, 2021-07-30T01:54:00.000+0000)</td><td>19eeda6f-0489-4c68-937a-f91ba866643b</td><td>9</td></tr><tr><td>List(2021-07-30T01:53:00.000+0000, 2021-07-30T01:54:00.000+0000)</td><td>afa56211-c75c-4d76-9f17-2e550cd51fa8</td><td>9</td></tr><tr><td>List(2021-07-30T01:53:00.000+0000, 2021-07-30T01:54:00.000+0000)</td><td>a529fb2a-5f7c-4aa1-976c-e4b683b919f2</td><td>9</td></tr><tr><td>List(2021-07-30T01:53:00.000+0000, 2021-07-30T01:54:00.000+0000)</td><td>66ce2ce6-3b23-4f92-a3b7-a7dfd3fe7caf</td><td>9</td></tr><tr><td>List(2021-07-30T01:53:00.000+0000, 2021-07-30T01:54:00.000+0000)</td><td>c7bb7aa9-cc1c-453f-a86e-ca171c710e85</td><td>9</td></tr><tr><td>List(2021-07-30T01:53:00.000+0000, 2021-07-30T01:54:00.000+0000)</td><td>a1a4b4ba-7f9c-4058-aa15-b79f3fd5dd7d</td><td>8</td></tr><tr><td>List(2021-07-30T01:53:00.000+0000, 2021-07-30T01:54:00.000+0000)</td><td>c91ff0d5-bffc-458f-9a15-25fac0fc6cc8</td><td>9</td></tr><tr><td>List(2021-07-30T01:53:00.000+0000, 2021-07-30T01:54:00.000+0000)</td><td>45e71b4f-f46e-4e58-959d-e2afa7830875 ...

# %%
# %sql
SELECT * FROM VehiclechkpointKafkaEventHub_Delta_Agg_Tumbling where id='c7bb7aa9-cc1c-453f-a86e-ca171c710e85'
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>window</th><th>id</th><th>count</th></tr></thead><tbody><tr><td>List(2021-07-30T01:54:00.000+0000, 2021-07-30T01:55:00.000+0000)</td><td>c7bb7aa9-cc1c-453f-a86e-ca171c710e85</td><td>10</td></tr><tr><td>List(2021-07-30T01:55:00.000+0000, 2021-07-30T01:56:00.000+0000)</td><td>c7bb7aa9-cc1c-453f-a86e-ca171c710e85</td><td>2</td></tr><tr><td>List(2021-07-30T01:53:00.000+0000, 2021-07-30T01:54:00.000+0000)</td><td>c7bb7aa9-cc1c-453f-a86e-ca171c710e85</td><td>9</td></tr></tbody></table></div>

# %% [markdown]
# ### Overlapping windows time with sliding time

# %%
for s in spark.streams.active:
    s.stop()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
kafkajsonDF.groupBy(window('timestamp',"2 minutes","1 minutes"),'id').count().orderBy('window') \
.writeStream.format("delta") \
.outputMode("complete") \
.option("truncate", "false") \
.option("checkpointLocation", "dbfs:/Vehiclechkpointkafkaeventhub_Agg_Chkpoint_Overlapping5/") \
.option("mergeSchema", "true") \
.start("dbfs:/VehiclechkpointKafkaEventHub_Delta_Agg_Overlapping5")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[15]: &lt;pyspark.sql.streaming.StreamingQuery at 0x7fdcf591fa90&gt;</div>

# %%
# %sql
-- Creating the table on delta location
DROP  TABLE IF EXISTS VehiclechkpointKafkaEventHub_Delta_Agg_Overlapping;
CREATE TABLE IF NOT EXISTS VehiclechkpointKafkaEventHub_Delta_Agg_Overlapping
USING DELTA
LOCATION "dbfs:/VehiclechkpointKafkaEventHub_Delta_Agg_Overlapping5/"
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>

# %%
# %sql
select * from VehiclechkpointKafkaEventHub_Delta_Agg_Overlapping
order by window desc
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>window</th><th>id</th><th>count</th></tr></thead><tbody><tr><td>List(2021-07-30T03:07:00.000+0000, 2021-07-30T03:09:00.000+0000)</td><td>c2c7cb35-2f97-4fab-ab23-62fe24eca7af</td><td>6</td></tr><tr><td>List(2021-07-30T03:07:00.000+0000, 2021-07-30T03:09:00.000+0000)</td><td>fc806137-2796-426b-be35-b5e76db9af16</td><td>6</td></tr><tr><td>List(2021-07-30T03:07:00.000+0000, 2021-07-30T03:09:00.000+0000)</td><td>14b522d2-e33d-4dd5-a8fe-9a7e637f1cc9</td><td>7</td></tr><tr><td>List(2021-07-30T03:07:00.000+0000, 2021-07-30T03:09:00.000+0000)</td><td>c872c0b8-4880-48e3-a981-a9430ed2effb</td><td>6</td></tr><tr><td>List(2021-07-30T03:07:00.000+0000, 2021-07-30T03:09:00.000+0000)</td><td>96d491ff-11ef-4518-82b8-59c0ce521595</td><td>6</td></tr><tr><td>List(2021-07-30T03:07:00.000+0000, 2021-07-30T03:09:00.000+0000)</td><td>94055835-edea-45a6-95db-0a17d0d3dac6</td><td>6</td></tr><tr><td>List(2021-07-30T03:07:00.000+0000, 2021-07-30T03:09:00.000+0000)</td><td>544f5760-81bf-478c-b78a-f3cbba753d37</td><td>6</td></tr><tr><td>List(2021-07-30T03:07:00.000+0000, 2021-07-30T03:09:00.000+0000)</td><td>ff9bff56-b8be-4668-bb81-acc68da68c50</td><td>6</td></tr><tr><td>List(2021-07-30T03:07:00.000+0000, 2021-07-30T03:09:00.000+0000)</td><td>0efe5ed2-7fc8-4544-b6eb-3016b2faa436</td><td>6</td></tr><tr><td>List(2021-07-30T03:07:00.000+0000, 2021-07-30T03:09:00.000+0000)</td><td>469cc591-fdc7-4f46-a721-a1a80554c359</td><td>6</td></tr><tr><td>List(2021-07-30T03:06:00.000+0000, 2021-07-30T03:08:00.000+0000)</td><td>ff9bff56-b8be-4668-bb81-acc68da68c50</td><td>17</td></tr><tr><td>List(2021-07-30T03:06:00.000+0000, 2021-07-30T03:08:00.000+0000)</td><td>c872c0b8-4880-48e3-a981-a9430ed2effb</td><td>17</td></tr><tr><td>List(2021-07-30T03:06:00.000+0000, 2021-07-30T03:08:00.000+0000)</td><td>544f5760-81bf-478c-b78a-f3cbba753d37</td><td>18</td></tr><tr><td>List(2021-07-30T03:06:00.000+0000, 2021-07-30T03:08:00.000+0000)</td><td>96d491ff-11ef-4518-82b8-59c0ce521595</td><td>18</td></tr><tr><td>List(2021-07-30T03:06:00.000+0000, 2021-07-30T03:08:00.000+0000)</td><td>469cc591-fdc7-4f46-a721-a1a80554c359</td><td>18</td></tr><tr><td>List(2021-07-30T03:06:00.000+0000, 2021-07-30T03:08:00.000+0000)</td><td>c2c7cb35-2f97-4fab-ab23-62fe24eca7af</td><td>17</td></tr><tr><td>List(2021-07-30T03:06:00.000+0000, 2021-07-30T03:08:00.000+0000)</td><td>0efe5ed2-7fc8-4544-b6eb-3016b2faa436</td><td>17</td></tr><tr><td>List(2021-07-30T03:06:00.000+0000, 2021-07-30T03:08:00.000+0000)</td><td>fc806137-2796-426b-be35-b5e76db9af16</td><td>18</td></tr><tr><td>List(2021-07-30T03:06:00.000+0000, 2021-07-30T03:08:00.000+0000)</td><td>14b522d2-e33d-4dd5-a8fe-9a7e637f1cc9</td><td>18</td></tr><tr><td>List(2021-07-30T03:06:00.000+0000, 2021-07-30T03:08:00.000+0000)</td><td>94055835-edea-45a6-95db-0a17d0d3dac6</td><td>18</td></tr><tr><td>List(2021-07-30T03:05:00.000+0000, 2021-07-30T03:07:00.000+0000)</td><td>544f5760-81bf-478c-b78a-f3cbba753d37</td><td>14</td></tr><tr><td>List(2021-07-30T03:05:00.000+0000, 2021-07-30T03:07:00.000+0000)</td><td>14b522d2-e33d-4dd5-a8fe-9a7e637f1cc9</td><td>13</td></tr><tr><td>List(2021-07-30T03:05:00.000+0000, 2021-07-30T03:07:00.000+0000)</td><td>c872c0b8-4880-48e3-a981-a9430ed2effb</td><td>14</td></tr><tr><td>List(2021-07-30T03:05:00.000+0000, 2021-07-30T03:07:00.000+0000)</td><td>fc806137-2796-426b-be35-b5e76db9af16</td><td>14</td></tr><tr><td>List(2021-07-30T03:05:00.000+0000, 2021-07-30T03:07:00.000+0000)</td><td>c2c7cb35-2f97-4fab-ab23-62fe24eca7af</td><td>14</td></tr><tr><td>List(2021-07-30T03:05:00.000+0000, 2021-07-30T03:07:00.000+0000)</td><td>ff9bff56-b8be-4668-bb81-acc68da68c50</td><td>14</td></tr><tr><td>List(2021-07-30T03:05:00.000+0000, 2021-07-30T03:07:00.000+0000)</td><td>0efe5ed2-7fc8-4544-b6eb-3016b2faa436</td><td>14</td></tr><tr><td>List(2021-07-30T03:05:00.000+0000, 2021-07-30T03:07:00.000+0000)</td><td>469cc591-fdc7-4f46-a721-a1a8 ...

# %%
# %sql
select * from VehiclechkpointKafkaEventHub_Delta_Agg_Overlapping
order by window desc
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>window</th><th>id</th><th>count</th></tr></thead><tbody><tr><td>List(2021-07-30T03:07:00.000+0000, 2021-07-30T03:09:00.000+0000)</td><td>c2c7cb35-2f97-4fab-ab23-62fe24eca7af</td><td>12</td></tr><tr><td>List(2021-07-30T03:07:00.000+0000, 2021-07-30T03:09:00.000+0000)</td><td>fc806137-2796-426b-be35-b5e76db9af16</td><td>12</td></tr><tr><td>List(2021-07-30T03:07:00.000+0000, 2021-07-30T03:09:00.000+0000)</td><td>14b522d2-e33d-4dd5-a8fe-9a7e637f1cc9</td><td>14</td></tr><tr><td>List(2021-07-30T03:07:00.000+0000, 2021-07-30T03:09:00.000+0000)</td><td>c872c0b8-4880-48e3-a981-a9430ed2effb</td><td>12</td></tr><tr><td>List(2021-07-30T03:07:00.000+0000, 2021-07-30T03:09:00.000+0000)</td><td>96d491ff-11ef-4518-82b8-59c0ce521595</td><td>12</td></tr><tr><td>List(2021-07-30T03:07:00.000+0000, 2021-07-30T03:09:00.000+0000)</td><td>94055835-edea-45a6-95db-0a17d0d3dac6</td><td>12</td></tr><tr><td>List(2021-07-30T03:07:00.000+0000, 2021-07-30T03:09:00.000+0000)</td><td>544f5760-81bf-478c-b78a-f3cbba753d37</td><td>12</td></tr><tr><td>List(2021-07-30T03:07:00.000+0000, 2021-07-30T03:09:00.000+0000)</td><td>ff9bff56-b8be-4668-bb81-acc68da68c50</td><td>12</td></tr><tr><td>List(2021-07-30T03:07:00.000+0000, 2021-07-30T03:09:00.000+0000)</td><td>0efe5ed2-7fc8-4544-b6eb-3016b2faa436</td><td>12</td></tr><tr><td>List(2021-07-30T03:07:00.000+0000, 2021-07-30T03:09:00.000+0000)</td><td>469cc591-fdc7-4f46-a721-a1a80554c359</td><td>12</td></tr><tr><td>List(2021-07-30T03:06:00.000+0000, 2021-07-30T03:08:00.000+0000)</td><td>ff9bff56-b8be-4668-bb81-acc68da68c50</td><td>34</td></tr><tr><td>List(2021-07-30T03:06:00.000+0000, 2021-07-30T03:08:00.000+0000)</td><td>c872c0b8-4880-48e3-a981-a9430ed2effb</td><td>34</td></tr><tr><td>List(2021-07-30T03:06:00.000+0000, 2021-07-30T03:08:00.000+0000)</td><td>544f5760-81bf-478c-b78a-f3cbba753d37</td><td>36</td></tr><tr><td>List(2021-07-30T03:06:00.000+0000, 2021-07-30T03:08:00.000+0000)</td><td>96d491ff-11ef-4518-82b8-59c0ce521595</td><td>36</td></tr><tr><td>List(2021-07-30T03:06:00.000+0000, 2021-07-30T03:08:00.000+0000)</td><td>469cc591-fdc7-4f46-a721-a1a80554c359</td><td>36</td></tr><tr><td>List(2021-07-30T03:06:00.000+0000, 2021-07-30T03:08:00.000+0000)</td><td>c2c7cb35-2f97-4fab-ab23-62fe24eca7af</td><td>34</td></tr><tr><td>List(2021-07-30T03:06:00.000+0000, 2021-07-30T03:08:00.000+0000)</td><td>0efe5ed2-7fc8-4544-b6eb-3016b2faa436</td><td>34</td></tr><tr><td>List(2021-07-30T03:06:00.000+0000, 2021-07-30T03:08:00.000+0000)</td><td>fc806137-2796-426b-be35-b5e76db9af16</td><td>36</td></tr><tr><td>List(2021-07-30T03:06:00.000+0000, 2021-07-30T03:08:00.000+0000)</td><td>14b522d2-e33d-4dd5-a8fe-9a7e637f1cc9</td><td>36</td></tr><tr><td>List(2021-07-30T03:06:00.000+0000, 2021-07-30T03:08:00.000+0000)</td><td>94055835-edea-45a6-95db-0a17d0d3dac6</td><td>36</td></tr><tr><td>List(2021-07-30T03:05:00.000+0000, 2021-07-30T03:07:00.000+0000)</td><td>544f5760-81bf-478c-b78a-f3cbba753d37</td><td>28</td></tr><tr><td>List(2021-07-30T03:05:00.000+0000, 2021-07-30T03:07:00.000+0000)</td><td>14b522d2-e33d-4dd5-a8fe-9a7e637f1cc9</td><td>26</td></tr><tr><td>List(2021-07-30T03:05:00.000+0000, 2021-07-30T03:07:00.000+0000)</td><td>c872c0b8-4880-48e3-a981-a9430ed2effb</td><td>28</td></tr><tr><td>List(2021-07-30T03:05:00.000+0000, 2021-07-30T03:07:00.000+0000)</td><td>fc806137-2796-426b-be35-b5e76db9af16</td><td>28</td></tr><tr><td>List(2021-07-30T03:05:00.000+0000, 2021-07-30T03:07:00.000+0000)</td><td>c2c7cb35-2f97-4fab-ab23-62fe24eca7af</td><td>28</td></tr><tr><td>List(2021-07-30T03:05:00.000+0000, 2021-07-30T03:07:00.000+0000)</td><td>ff9bff56-b8be-4668-bb81-acc68da68c50</td><td>28</td></tr><tr><td>List(2021-07-30T03:05:00.000+0000, 2021-07-30T03:07:00.000+0000)</td><td>0efe5ed2-7fc8-4544-b6eb-3016b2faa436</td><td>28</td></tr><tr><td>List(2021-07-30T03:05:00.000+0000, 2021-07-30T03:07:00.000+0000)</td><td>469cc591-fdc7-4f46 ...

# %%
# %sql
select * from VehiclechkpointKafkaEventHub_Delta_Agg_Overlapping
where id ='c2c7cb35-2f97-4fab-ab23-62fe24eca7af' 
order by window desc
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>window</th><th>id</th><th>count</th></tr></thead><tbody><tr><td>List(2021-07-30T03:08:00.000+0000, 2021-07-30T03:10:00.000+0000)</td><td>c2c7cb35-2f97-4fab-ab23-62fe24eca7af</td><td>2</td></tr><tr><td>List(2021-07-30T03:07:00.000+0000, 2021-07-30T03:09:00.000+0000)</td><td>c2c7cb35-2f97-4fab-ab23-62fe24eca7af</td><td>14</td></tr><tr><td>List(2021-07-30T03:06:00.000+0000, 2021-07-30T03:08:00.000+0000)</td><td>c2c7cb35-2f97-4fab-ab23-62fe24eca7af</td><td>34</td></tr><tr><td>List(2021-07-30T03:05:00.000+0000, 2021-07-30T03:07:00.000+0000)</td><td>c2c7cb35-2f97-4fab-ab23-62fe24eca7af</td><td>28</td></tr><tr><td>List(2021-07-30T03:04:00.000+0000, 2021-07-30T03:06:00.000+0000)</td><td>c2c7cb35-2f97-4fab-ab23-62fe24eca7af</td><td>6</td></tr></tbody></table></div>

# %% [markdown]
# ##### After Inserting records for the time frame 2021-07-30T03:08:30.000+0000
#
# c2c7cb35-2f97-4fab-ab23-62fe24eca7af

# %%
# %sql
select * from VehiclechkpointKafkaEventHub_Delta_Agg_Overlapping
where id ='c2c7cb35-2f97-4fab-ab23-62fe24eca7af' 
order by window desc
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>window</th><th>id</th><th>count</th></tr></thead><tbody><tr><td>List(2021-07-30T03:08:00.000+0000, 2021-07-30T03:10:00.000+0000)</td><td>c2c7cb35-2f97-4fab-ab23-62fe24eca7af</td><td>2</td></tr><tr><td>List(2021-07-30T03:07:00.000+0000, 2021-07-30T03:09:00.000+0000)</td><td>c2c7cb35-2f97-4fab-ab23-62fe24eca7af</td><td>14</td></tr><tr><td>List(2021-07-30T03:06:00.000+0000, 2021-07-30T03:08:00.000+0000)</td><td>c2c7cb35-2f97-4fab-ab23-62fe24eca7af</td><td>34</td></tr><tr><td>List(2021-07-30T03:05:00.000+0000, 2021-07-30T03:07:00.000+0000)</td><td>c2c7cb35-2f97-4fab-ab23-62fe24eca7af</td><td>28</td></tr><tr><td>List(2021-07-30T03:04:00.000+0000, 2021-07-30T03:06:00.000+0000)</td><td>c2c7cb35-2f97-4fab-ab23-62fe24eca7af</td><td>6</td></tr></tbody></table></div>
