# %%
from pyspark.sql.types import *
from pyspark.sql.functions import col
from pyspark.sql.functions import col,sum,avg,max
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
dbutils.fs.ls("dbfs:/mnt/Gen2/Customer/csvFiles")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[2]: [FileInfo(path=&#39;dbfs:/mnt/Gen2/Customer/csvFiles/part-00000-tid-3200334632332214470-9b4dec79-7e2e-495d-8657-3b5457ed3753-108-1-c000.csv&#39;, name=&#39;part-00000-tid-3200334632332214470-9b4dec79-7e2e-495d-8657-3b5457ed3753-108-1-c000.csv&#39;, size=2423786),
#  FileInfo(path=&#39;dbfs:/mnt/Gen2/Customer/csvFiles/part-00001-tid-3200334632332214470-9b4dec79-7e2e-495d-8657-3b5457ed3753-109-1-c000.csv&#39;, name=&#39;part-00001-tid-3200334632332214470-9b4dec79-7e2e-495d-8657-3b5457ed3753-109-1-c000.csv&#39;, size=2423268),
#  FileInfo(path=&#39;dbfs:/mnt/Gen2/Customer/csvFiles/part-00002-tid-3200334632332214470-9b4dec79-7e2e-495d-8657-3b5457ed3753-110-1-c000.csv&#39;, name=&#39;part-00002-tid-3200334632332214470-9b4dec79-7e2e-495d-8657-3b5457ed3753-110-1-c000.csv&#39;, size=2427801),
#  FileInfo(path=&#39;dbfs:/mnt/Gen2/Customer/csvFiles/part-00003-tid-3200334632332214470-9b4dec79-7e2e-495d-8657-3b5457ed3753-111-1-c000.csv&#39;, name=&#39;part-00003-tid-3200334632332214470-9b4dec79-7e2e-495d-8657-3b5457ed3753-111-1-c000.csv&#39;, size=2419248),
#  FileInfo(path=&#39;dbfs:/mnt/Gen2/Customer/csvFiles/part-00004-tid-3200334632332214470-9b4dec79-7e2e-495d-8657-3b5457ed3753-112-1-c000.csv&#39;, name=&#39;part-00004-tid-3200334632332214470-9b4dec79-7e2e-495d-8657-3b5457ed3753-112-1-c000.csv&#39;, size=2425732),
#  FileInfo(path=&#39;dbfs:/mnt/Gen2/Customer/csvFiles/part-00005-tid-3200334632332214470-9b4dec79-7e2e-495d-8657-3b5457ed3753-113-1-c000.csv&#39;, name=&#39;part-00005-tid-3200334632332214470-9b4dec79-7e2e-495d-8657-3b5457ed3753-113-1-c000.csv&#39;, size=2419015),
#  FileInfo(path=&#39;dbfs:/mnt/Gen2/Customer/csvFiles/part-00006-tid-3200334632332214470-9b4dec79-7e2e-495d-8657-3b5457ed3753-114-1-c000.csv&#39;, name=&#39;part-00006-tid-3200334632332214470-9b4dec79-7e2e-495d-8657-3b5457ed3753-114-1-c000.csv&#39;, size=2422780),
#  FileInfo(path=&#39;dbfs:/mnt/Gen2/Customer/csvFiles/part-00007-tid-3200334632332214470-9b4dec79-7e2e-495d-8657-3b5457ed3753-115-1-c000.csv&#39;, name=&#39;part-00007-tid-3200334632332214470-9b4dec79-7e2e-495d-8657-3b5457ed3753-115-1-c000.csv&#39;, size=2421433),
#  FileInfo(path=&#39;dbfs:/mnt/Gen2/Customer/csvFiles/part-00008-tid-3200334632332214470-9b4dec79-7e2e-495d-8657-3b5457ed3753-116-1-c000.csv&#39;, name=&#39;part-00008-tid-3200334632332214470-9b4dec79-7e2e-495d-8657-3b5457ed3753-116-1-c000.csv&#39;, size=2421195),
#  FileInfo(path=&#39;dbfs:/mnt/Gen2/Customer/csvFiles/part-00009-tid-3200334632332214470-9b4dec79-7e2e-495d-8657-3b5457ed3753-117-1-c000.csv&#39;, name=&#39;part-00009-tid-3200334632332214470-9b4dec79-7e2e-495d-8657-3b5457ed3753-117-1-c000.csv&#39;, size=2422384)]</div>

# %%
# Reading customer csf files in a dataframe with specifying the schema explicitly
df_cust= spark.read.format("csv").option("header",True).option("inferSchema", True).load("dbfs:/mnt/Gen2/Customer/csvFiles")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# Getting the number of partitions
print(f" Number of partitions with all files read = {df_cust.rdd.getNumPartitions()}")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"> Number of partitions with all files read = 10
# </div>

# %%
#Creating the schema for the Customer csv files
cust_schema = StructType([
    StructField("C_CUSTKEY", IntegerType()),
    StructField("C_NAME", StringType()),
    StructField("C_ADDRESS", StringType()),
    StructField("C_NATIONKEY", ShortType()),
    StructField("C_PHONE", StringType()),
    StructField("C_ACCTBAL", DoubleType()),
    StructField("C_MKTSEGMENT", StringType()),
    StructField("C_COMMENT", StringType())
])
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
#Creating the dataframe by specifying the schema using .schem() option. We don;t see any DAG getting created with schema is specified
df_cust_sch= spark.read.format("csv").option("header",True).schema(cust_schema).load("/mnt/Gen2/Customer/csvFiles/")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# Using first file 
df_cust_sch= spark.read.format("csv").option("header",True).load("/mnt/Gen2/Customer/csvFiles/part-00000-tid-3200334632332214470-9b4dec79-7e2e-495d-8657-3b5457ed3753-108-1-c000.csv")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
#Getting the number of partitions by specifying only one csv file.
print(f" Number of partitions with 1 file read  = {df_cust_sch.rdd.getNumPartitions()}")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"> Number of partitions with 1 file read  = 1
# </div>
